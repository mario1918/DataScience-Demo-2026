# %% [markdown]
# <a href="https://colab.research.google.com/github/mario1918/DataScience-Demo-2026/blob/main/data_science_portfolio_notebook.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Ingest

# %% [markdown]
# COVID data from https://github.com/nytimes/covid-19-data

# %%
import pandas as pd
df = pd.read_csv("https://raw.githubusercontent.com/nytimes/covid-19-data/master/us-states.csv")
df.head()
# Out:
#          date       state  fips  cases  deaths
# 0  2020-01-21  Washington    53      1       0
# 1  2020-01-22  Washington    53      1       0
# 2  2020-01-23  Washington    53      1       0
# 3  2020-01-24    Illinois    17      1       0
# 4  2020-01-24  Washington    53      1       0

# %% [markdown]
# Last five rows

# %%
df.tail()
# Out:
#              date          state  fips    cases  deaths
# 61937  2023-03-23       Virginia    51  2298300   23782
# 61938  2023-03-23     Washington    53  1940704   15905
# 61939  2023-03-23  West Virginia    54   645710    8132
# 61940  2023-03-23      Wisconsin    55  2014524   16485
# 61941  2023-03-23        Wyoming    56   185800    2014

# %% [markdown]
# What are the columns?

# %%
df.columns
# Out:
# Index(['date', 'state', 'fips', 'cases', 'deaths'], dtype='object')

# %% [markdown]
# What is the shape of this dataframe? (rows,columns)

# %%
df.shape
# Out:
# (61942, 5)

# %% [markdown]
# ## EDA

# %% [markdown]
# What are the characteristics of the data?

# %%
df.describe()
# Out:
#                fips         cases         deaths
# count  61942.000000  6.194200e+04   61942.000000
# mean      32.247958  8.898301e+05   11779.067499
# std       18.788383  1.470231e+06   17345.774849
# min        1.000000  1.000000e+00       0.000000
# 25%       17.000000  7.078350e+04    1171.000000
# 50%       31.000000  3.514960e+05    5035.000000
# 75%       46.000000  1.043231e+06   14912.000000
# max       78.000000  1.216916e+07  104277.000000

# %%
import seaborn as sns
sns.scatterplot(x="cases", y="deaths", data=df)
# Out:
# <Axes: xlabel='cases', ylabel='deaths'>

# %% [markdown]
# ## Data-based EDA

# %%
df = pd.read_csv("https://raw.githubusercontent.com/nytimes/covid-19-data/master/us-states.csv")
df['date'] = pd.to_datetime(df['date'])
df = df.set_index(df['date'])
print(df.columns)
df.index
# Out:
# Index(['date', 'state', 'fips', 'cases', 'deaths'], dtype='object')
# DatetimeIndex(['2020-01-21', '2020-01-22', '2020-01-23', '2020-01-24',
#                '2020-01-24', '2020-01-25', '2020-01-25', '2020-01-25',
#                '2020-01-26', '2020-01-26',
#                ...
#                '2023-03-23', '2023-03-23', '2023-03-23', '2023-03-23',
#                '2023-03-23', '2023-03-23', '2023-03-23', '2023-03-23',
#                '2023-03-23', '2023-03-23'],
#               dtype='datetime64[ns]', name='date', length=61942, freq=None)

# %%
from datetime import date, timedelta
today = date.today()
daybefore = today - timedelta(days = 2)
print(f"Today is {today}")
print(f"Two days ago is: {daybefore}")
# Out:
# Today is 2026-05-30
# Two days ago is: 2026-05-28

# %%
df.loc[daybefore:today].head()
# Out:
# Empty DataFrame
# Columns: [date, state, fips, cases, deaths]
# Index: []

# %%
current_df = df.sort_values(by=["deaths", "cases"], ascending= False)

# %%
current_df.head(10)
# Out:
#                  date       state  fips     cases  deaths
# date
# 2023-03-23 2023-03-23  California     6  12169158  104277
# 2023-03-22 2023-03-22  California     6  12155467  104196
# 2023-03-21 2023-03-21  California     6  12154941  104185
# 2023-03-20 2023-03-20  California     6  12154293  104165
# 2023-03-19 2023-03-19  California     6  12153083  104130
# 2023-03-17 2023-03-17  California     6  12153079  104130
# 2023-03-18 2023-03-18  California     6  12153079  104130
# 2023-03-16 2023-03-16  California     6  12152129  104114
# 2023-03-15 2023-03-15  California     6  12136243  104047
# 2023-03-14 2023-03-14  California     6  12135588  104038

# %%
cu

# %% [markdown]
# ## Modeling

# %% [markdown]
# ## Conclusion
